# %%
# !pip install -U adapter-transformers datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting adapter-transformers
#   Downloading adapter_transformers-3.2.1-py3-none-any.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 91.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 54.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.11.0 (from adapter-transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from adapter-transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 34.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from adapter-transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 78.4 MB/s eta 0:00:00
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 21.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->adapter-transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->adapter-transformers) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, adapter-transformers, datasets
# Successfully installed adapter-transformers-3.2.1 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.12.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.15.1 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.3 xxhash-3.2.0 yarl-1.9.2

# %%
from datasets import load_dataset, load_metric
raw_datasets = load_dataset('squad_v2')
# Out:
# Downloading builder script:   0%|          | 0.00/5.28k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.02k [00:00<?, ?B/s]
# Downloading and preparing dataset squad_v2/squad_v2 to /root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.55M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/801k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]
# Dataset squad_v2 downloaded and prepared to /root/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/

# %%
do_train = True # False
do_eval = True 

# epochs, bs, GA
evaluation_strategy = "epoch" # no

# fp16
fp16_opt_level = 'O1'
fp16_backend = "auto"
fp16_full_eval = False

# optimizer (AdamW)
weight_decay = 0.01 # 0.0
adam_beta1 = 0.9
adam_beta2 = 0.999

# scheduler
lr_scheduler_type = 'linear'
warmup_ratio = 0.0
warmup_steps = 0

# logs
logging_strategy = "steps"
logging_first_step = True # False
logging_steps = 500     # if strategy = "steps"
eval_steps = logging_steps # logging_steps

# checkpoints
save_strategy = "epoch" # steps
save_steps = 1000 # if save_strategy = "steps"
save_total_limit = 1 # None

# no cuda, seed
no_cuda = False
seed = 42

# bar
disable_tqdm = False # True
remove_unused_columns = True
path_to_outputs = "./outputs"

# subfolder for model outputs
output_dir = path_to_outputs + '/output_dir' 
overwrite_output_dir = True # False

# logs
logging_dir = path_to_outputs + '/logging_dir'
batch_size = 16
gradient_accumulation_steps = 1

learning_rate = 1e-4
num_train_epochs = 1 #3

adam_epsilon = 1e-7

fp16 = True

# best model
load_best_model_at_end = True 
metric_for_best_model = "loss"
greater_is_better = False

# %%
from transformers import AutoTokenizer, RobertaTokenizerFast

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
max_length = 384 # The maximum length of a feature (question and context)
doc_stride = 128

# %%
def prepare_train_features(examples):
    # Tokenize our examples with truncation and padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    examples["question"] = [q.lstrip() for q in examples["question"]]
    tokenized_examples = tokenizer(
        examples["question" if pad_on_right else "context"],
        examples["context" if pad_on_right else "question"],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    # The offset mappings will give us a map from token to character position in the original context. This will
    # help us compute the start_positions and end_positions.
    offset_mapping = tokenized_examples.pop("offset_mapping")

    # Let's label those examples!
    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        cls_index = input_ids.index(tokenizer.cls_token_id)

        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        answers = examples["answers"][sample_index]
        # If no answers are given, set the cls_index as answer.
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Start/end character index of the answer in the text.
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Start token index of the current span in the text.
            token_start_index = 0
            while sequence_ids[token_start_index] != (1 if pad_on_right else 0):
                token_start_index += 1

            # End token index of the current span in the text.
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1 if pad_on_right else 0):
                token_end_index -= 1

            # Detect if the answer is out of the span (in which case this feature is labeled with the CLS index).
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                # Otherwise move the token_start_index and token_end_index to the two ends of the answer.
                # Note: we could go after the last offset if the answer is the last word (edge case).
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# %%
pad_on_right = tokenizer.padding_side == "right"
tokenized_datasets = raw_datasets.map(prepare_train_features, batched=True, remove_columns=raw_datasets["train"].column_names)
# Out:
# Map:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer

model = AutoModelForQuestionAnswering.from_pretrained("roberta-base")
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.dense.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import list_adapters

adapter_infos = list_adapters(source="hf", model_name="roberta-base")
#adapter_infos

# %%
# for name, p in model.named_parameters():
#   if p.requires_grad == True:
#     print(name)

# %%
#adapter_name = model.load_adapter("UKP-SQuARE/MADE_TriviaQA_Adapter", source="hf")
from transformers.adapters.composition import Fuse
model.load_adapter("UKP-SQuARE/MADE_TriviaQA_Adapter", source="hf")
model.load_adapter("UKP-SQuARE/MADE_SQuAD_Adapter", source="hf")
model.add_adapter_fusion(Fuse("TriviaQA", "SQuAD"))
model.set_active_adapters(Fuse("TriviaQA", "SQuAD"))
#model.set_active_adapters = adapter_name
#model.train_adapter(["TriviaQA"])
adapter_setup = Fuse("TriviaQA", "SQuAD")
model.train_adapter_fusion(adapter_setup)
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading (…)a04e32ae2e/README.md:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading (…)e2e/head_config.json:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading (…)2ae2e/.gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading (…)/adapter_config.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# Downloading pytorch_model_head.bin:   0%|          | 0.00/7.25k [00:00<?, ?B/s]
# Downloading pytorch_adapter.bin:   0%|          | 0.00/7.19M [00:00<?, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading (…)9cf/head_config.json:   0%|          | 0.00/262 [00:00<?, ?B/s]
# Downloading (…)/adapter_config.json:   0%|          | 0.00/1.03k [00:00<?, ?B/s]
# Downloading (…)2f9c1389cf/README.md:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# Downloading (…)389cf/.gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading pytorch_model_head.bin:   0%|          | 0.00/7.25k [00:00<?, ?B/s]
# Downloading pytorch_adapter.bin:   0%|          | 0.00/7.19M [00:00<?, ?B/s]

# %%
for name, p in model.named_parameters():
  if p.requires_grad == True:
    print(name)
# Out:
# roberta.encoder.layer.0.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.0.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.0.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.0.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.0.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.0.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.0.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.0.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.0.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.0.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.1.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.1.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.1.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.1.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.1.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.1.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.1.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.1.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.1.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.1.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.2.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.2.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.2.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.2.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.2.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.2.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.2.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.2.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.2.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.2.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.3.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.3.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.3.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.3.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.3.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.3.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.3.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.3.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.3.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.3.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.4.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.4.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.4.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.4.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.4.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.4.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.4.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.4.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.4.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.4.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.5.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.5.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.5.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.5.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.5.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.5.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.5.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.5.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.5.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.5.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.6.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.6.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.6.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.6.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.6.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.6.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.6.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.6.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.6.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.6.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.7.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.7.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.7.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.7.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.7.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.7.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.7.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.7.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.7.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.7.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.8.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.8.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.8.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.8.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.8.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.8.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.8.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.8.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.8.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.8.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.9.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.9.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.9.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.9.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.9.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.9.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.9.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.9.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.9.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.9.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.10.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.10.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.10.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.10.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.10.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.10.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.10.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.10.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.10.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.10.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.11.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.11.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.11.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.11.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.11.attention.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# roberta.encoder.layer.11.output.adapter_fusion_layer.TriviaQA,SQuAD.query.weight
# roberta.encoder.layer.11.output.adapter_fusion_layer.TriviaQA,SQuAD.query.bias
# roberta.encoder.layer.11.output.adapter_fusion_layer.TriviaQA,SQuAD.key.weight
# roberta.encoder.layer.11.output.adapter_fusion_layer.TriviaQA,SQuAD.key.bias
# roberta.encoder.layer.11.output.adapter_fusion_layer.TriviaQA,SQuAD.value.weight
# qa_outputs.weight
# qa_outputs.bias

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction
#from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
from datasets import load_metric

training_args = TrainingArguments(
        output_dir=output_dir,
        overwrite_output_dir=overwrite_output_dir,
        do_train=do_train,
        do_eval=do_eval,
        evaluation_strategy=evaluation_strategy,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=batch_size,
        gradient_accumulation_steps=gradient_accumulation_steps,
        learning_rate=learning_rate,
        weight_decay=weight_decay,
        adam_beta1=adam_beta1,
        adam_beta2=adam_beta2,
        adam_epsilon=adam_epsilon,
        num_train_epochs=num_train_epochs,
        lr_scheduler_type=lr_scheduler_type,
        warmup_ratio=warmup_ratio,
        warmup_steps=warmup_steps,
        logging_dir=logging_dir,         # directory for storing logs
        logging_strategy=evaluation_strategy,
        logging_steps=logging_steps,     # if strategy = "steps"
        save_strategy=evaluation_strategy,          # model checkpoint saving strategy
        save_steps=logging_steps,        # if strategy = "steps"
        save_total_limit=save_total_limit,
        fp16=fp16,
        eval_steps=logging_steps,        # if strategy = "steps"
        load_best_model_at_end=load_best_model_at_end,
        metric_for_best_model=metric_for_best_model,
        greater_is_better=greater_is_better
        )

# %%
from transformers.trainer_callback import EarlyStoppingCallback
from transformers import default_data_collator

data_collator = default_data_collator
train_adapter=True
#do_save_full_model=train_adapter, # save full model as we finetuned head + embeddings
trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator
    )
# Out:
# Using cuda_amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 131823
#   Num Epochs = 1
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 8239
#   Number of trainable parameters = 42505730
#     <div>
#
#       <progress value='8239' max='8239' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8239/8239 1:27:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.270000</td>
#       <td>0.912968</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 12165
#   Batch size = 16
# Saving model checkpoint to ./outputs/output_dir/checkpoint-8239
# Configuration saved in ./outputs/output_dir/checkpoint-8239/TriviaQA/adapter_config.json
# Module weights saved in ./outputs/output_dir/checkpoint-8239/TriviaQA/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/checkpoint-8239/TriviaQA/head_config.json
# Module weights saved in ./outputs/output_dir/checkpoint-8239/TriviaQA/pytorch_model_head.bin
# Configuration saved in ./outputs/output_dir/checkpoint-8239/SQuAD/adapter_config.json
# Module weights saved in ./outputs/output_dir/checkpoint-8239/SQuAD/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/checkpoint-8239/SQuAD/head_config.json
# Module weights saved in ./outputs/output_dir/checkpoint-8239/SQuAD/pytorch_model_head.bin
# Configuration saved in ./outputs/output_dir/checkpoint-8239/TriviaQA,SQuAD/adapter_fusion_config.json
# Module weights saved in ./outputs/output_dir/checkpoint-8239/TriviaQA,SQuAD/pytorch_model_adapter_fusion.bin
# tokenizer config file saved in ./outputs/output_dir/checkpoint-8239/tokenizer_config.json
# Special tokens file saved in ./outputs/output_dir/checkpoint-8239/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best adapter(s) from ./outputs/output_dir/checkpoint-8239 (score: 0.9129675030708313).
# Loading module configuration from ./outputs/output_dir/checkpoint-8239/TriviaQA/adapter_config.json
# Overwriting existing adapter 'TriviaQA'.
# Loading module weights from ./outputs/output_dir/checkpoint-8239/TriviaQA/pytorch_adapter.bin
# Loading module configuration from ./outputs/output_dir/checkpoint-8239/TriviaQA/head_config.json
# Loading module weights from ./outputs/output_dir/checkpoint-8239/TriviaQA/pytorch_model_head.bin
# Loading module configuration from ./outputs/output_dir/checkpoint-8239/SQuAD/adapter_config.json
# Overwriting existing adapter 'SQuAD'.
# Loading module weights from ./outputs/output_dir/checkpoint-8239/SQuAD/pytorch_adapter.bin
# Loading module configuration from ./outputs/output_dir/checkpoint-8239/SQuAD/head_config.json
# Loading module weights from ./outputs/output_dir/checkpoint-8239/SQuAD/pytorch_model_head.bin
# Loading best adapter fusion(s) from ./outputs/output_dir/checkpoint-8239 (score: 0.9129675030708313).
# Loading module configuration from ./outputs/output_dir/checkpoint-8239/TriviaQA,SQuAD/adapter_fusion_config.json
# Overwriting existing adapter fusion module 'TriviaQA,SQuAD'
# Loading module weights from ./outputs/output_dir/checkpoint-8239/TriviaQA,SQuAD/pytorch_model_adapter_fusion.bin
# No matching prediction head found in './outputs/output_dir/checkpoint-8239/TriviaQA,SQuAD'
# Deleting older checkpoint [outputs/output_dir/checkpoint-8239] due to args.save_total_limit
# TrainOutput(global_step=8239, training_loss=1.2699625779448356, metrics={'train_runtime': 5241.5118, 'train_samples_per_second': 25.15, 'train_steps_per_second': 1.572, 'total_flos': 3.982981799108966e+16, 'train_loss': 1.2699625779448356, 'epoch': 1.0})

# %%
def prepare_validation_features(examples):
    # Tokenize our examples with truncation and maybe padding, but keep the overflows using a stride. This results
    # in one example possible giving several features when a context is long, each of those features having a
    # context that overlaps a bit the context of the previous feature.
    examples["question"] = [q.lstrip() for q in examples["question"]]
    tokenized_examples = tokenizer(
        examples["question" if pad_on_right else "context"],
        examples["context" if pad_on_right else "question"],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=max_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    # Since one example might give us several features if it has a long context, we need a map from a feature to
    # its corresponding example. This key gives us just that.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")

    # We keep the example_id that gave us this feature and we will store the offset mappings.
    tokenized_examples["example_id"] = []

    for i in range(len(tokenized_examples["input_ids"])):
        # Grab the sequence corresponding to that example (to know what is the context and what is the question).
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1 if pad_on_right else 0

        # One example can give several spans, this is the index of the example containing this span of text.
        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])

        # Set to None the offset_mapping that are not part of the context so it's easy to determine if a token
        # position is part of the context or not.
        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]

    return tokenized_examples

# %%
validation_features = raw_datasets["validation"].map(
    prepare_validation_features,
    batched=True,
    remove_columns=raw_datasets["validation"].column_names
)
# Out:
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
raw_predictions = trainer.predict(validation_features)
# Out:
# The following columns in the test set don't have a corresponding argument in `RobertaForQuestionAnswering.forward` and have been ignored: example_id, offset_mapping. If example_id, offset_mapping are not expected by `RobertaForQuestionAnswering.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 12165
#   Batch size = 16

# %%
validation_features.set_format(type=validation_features.format["type"], columns=list(validation_features.features.keys()))

# %%
max_answer_length = 30

# %%
from tqdm.auto import tqdm
import collections

def postprocess_qa_predictions(examples, features, raw_predictions, n_best_size = 20, max_answer_length = 30):
    all_start_logits, all_end_logits = raw_predictions
    # Build a map example to its corresponding features.
    example_id_to_index = {k: i for i, k in enumerate(examples["id"])}
    features_per_example = collections.defaultdict(list)
    for i, feature in enumerate(features):
        features_per_example[example_id_to_index[feature["example_id"]]].append(i)

    # The dictionaries we have to fill.
    predictions = collections.OrderedDict()

    # Logging.
    print(f"Post-processing {len(examples)} example predictions split into {len(features)} features.")

    # Let's loop over all the examples!
    for example_index, example in enumerate(tqdm(examples)):
        # Those are the indices of the features associated to the current example.
        feature_indices = features_per_example[example_index]

        min_null_score = None # Only used if squad_v2 is True.
        valid_answers = []
        
        context = example["context"]
        # Looping through all the features associated to the current example.
        for feature_index in feature_indices:
            # We grab the predictions of the model for this feature.
            start_logits = all_start_logits[feature_index]
            end_logits = all_end_logits[feature_index]
            # This is what will allow us to map some the positions in our logits to span of texts in the original
            # context.
            offset_mapping = features[feature_index]["offset_mapping"]

            # Update minimum null prediction.
            cls_index = features[feature_index]["input_ids"].index(tokenizer.cls_token_id)
            feature_null_score = start_logits[cls_index] + end_logits[cls_index]
            if min_null_score is None or min_null_score < feature_null_score:
                min_null_score = feature_null_score

            # Go through all possibilities for the `n_best_size` greater start and end logits.
            start_indexes = np.argsort(start_logits)[-1 : -n_best_size - 1 : -1].tolist()
            end_indexes = np.argsort(end_logits)[-1 : -n_best_size - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Don't consider out-of-scope answers, either because the indices are out of bounds or correspond
                    # to part of the input_ids that are not in the context.
                    if (
                        start_index >= len(offset_mapping)
                        or end_index >= len(offset_mapping)
                        or offset_mapping[start_index] is None
                        or offset_mapping[end_index] is None
                    ):
                        continue
                    # Don't consider answers with a length that is either < 0 or > max_answer_length.
                    if end_index < start_index or end_index - start_index + 1 > max_answer_length:
                        continue

                    start_char = offset_mapping[start_index][0]
                    end_char = offset_mapping[end_index][1]
                    valid_answers.append(
                        {
                            "score": start_logits[start_index] + end_logits[end_index],
                            "text": context[start_char: end_char]
                        }
                    )
        
        if len(valid_answers) > 0:
            best_answer = sorted(valid_answers, key=lambda x: x["score"], reverse=True)[0]
        else:
            # In the very rare edge case we have not a single non-null prediction, we create a fake prediction to avoid
            # failure.
            best_answer = {"text": "", "score": 0.0}
        
        # Let's pick our final answer: the best one or the null answer (only for squad_v2)
        #if not squad_v2:
        #    predictions[example["id"]] = best_answer["text"]
        #else:
        answer = best_answer["text"] if best_answer["score"] > min_null_score else ""
        predictions[example["id"]] = answer

    return predictions

# %%
final_predictions = postprocess_qa_predictions(raw_datasets["validation"], validation_features, raw_predictions.predictions)
# Out:
# Post-processing 11873 example predictions split into 12165 features.
#   0%|          | 0/11873 [00:00<?, ?it/s]

# %%
metric = load_metric("squad_v2")
formatted_predictions = [{"id": k, "prediction_text": v, "no_answer_probability": 0.0} for k, v in final_predictions.items()]
references = [{"id": ex["id"], "answers": ex["answers"]} for ex in raw_datasets["validation"]]
metric.compute(predictions=formatted_predictions, references=references)
# Out:
# <ipython-input-26-25da40bb1545>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("squad_v2")
# Downloading builder script:   0%|          | 0.00/2.25k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.19k [00:00<?, ?B/s]
# {'exact': 75.30531457929757,
#  'f1': 78.35703130832214,
#  'total': 11873,
#  'HasAns_exact': 72.65519568151147,
#  'HasAns_f1': 78.76738068888461,
#  'HasAns_total': 5928,
#  'NoAns_exact': 77.94785534062237,
#  'NoAns_f1': 77.94785534062237,
#  'NoAns_total': 5945,
#  'best_exact': 75.30531457929757,
#  'best_exact_thresh': 0.0,
#  'best_f1': 78.35703130832196,
#  'best_f1_thresh': 0.0}

# %%
trainer.model.save_adapter_fusion("./outputs/output_dir", "TriviaQA,SQuAD")
trainer.model.save_all_adapters("./outputs/output_dir")
# Out:
# Configuration saved in ./outputs/output_dir/adapter_fusion_config.json
# Module weights saved in ./outputs/output_dir/pytorch_model_adapter_fusion.bin
# Configuration saved in ./outputs/output_dir/TriviaQA/adapter_config.json
# Module weights saved in ./outputs/output_dir/TriviaQA/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/TriviaQA/head_config.json
# Module weights saved in ./outputs/output_dir/TriviaQA/pytorch_model_head.bin
# Configuration saved in ./outputs/output_dir/SQuAD/adapter_config.json
# Module weights saved in ./outputs/output_dir/SQuAD/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/SQuAD/head_config.json
# Module weights saved in ./outputs/output_dir/SQuAD/pytorch_model_head.bin

# %%
trainer.save_model("./outputs/output_dir")
# Out:
# Saving model checkpoint to ./outputs/output_dir
# Configuration saved in ./outputs/output_dir/TriviaQA/adapter_config.json
# Module weights saved in ./outputs/output_dir/TriviaQA/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/TriviaQA/head_config.json
# Module weights saved in ./outputs/output_dir/TriviaQA/pytorch_model_head.bin
# Configuration saved in ./outputs/output_dir/SQuAD/adapter_config.json
# Module weights saved in ./outputs/output_dir/SQuAD/pytorch_adapter.bin
# Configuration saved in ./outputs/output_dir/SQuAD/head_config.json
# Module weights saved in ./outputs/output_dir/SQuAD/pytorch_model_head.bin
# Configuration saved in ./outputs/output_dir/TriviaQA,SQuAD/adapter_fusion_config.json
# Module weights saved in ./outputs/output_dir/TriviaQA,SQuAD/pytorch_model_adapter_fusion.bin
# tokenizer config file saved in ./outputs/output_dir/tokenizer_config.json
# Special tokens file saved in ./outputs/output_dir/special_tokens_map.json
